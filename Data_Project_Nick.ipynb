# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %%
temp = pd.read_csv("Bitfinex_BTCEUR_trades_2018_02_02.csv")
temp
# Out:
#               id exchange  symbol           date        price    amount   sell
# 0      183601815       bf  btceur  1517529608000  7349.600000  0.004568  False
# 1      183601825       bf  btceur  1517529609000  7354.680450  0.010000   True
# 2      183601823       bf  btceur  1517529609000  7354.680450  0.004568   True
# 3      183601833       bf  btceur  1517529610000  7354.600000  0.102395  False
# 4      183601904       bf  btceur  1517529626000  7343.407500  0.086580  False
# 5      183601906       bf  btceur  1517529626000  7343.807250  0.204920  False
# 6      183602055       bf  btceur  1517529638000  7356.000000  0.300000  False
# 7      183602057       bf  btceur  1517529638000  7357.900000  0.088007  False
# 8      183602052       bf  btceur  1517529638000  7355.800000  0.100000  False
# 9      183602064       bf  btceur  1517529639000  7343.167650  0.088007  False
# 10     183602333       bf  btceur  1517529675000  7352.281950  0.002000   True
# ...

# %%
print(data1.loc[0])
# Out:
# id              183601815
# exchange               bf
# symbol             btceur
# date        1517529608000
# price              7349.6
# amount           0.004568
# sell                False
# Name: 0, dtype: object

# %%
data1.set_index("id", inplace = True)

# %%
data1['ALTERED_DATE'] = data1['date']/1000
data1['DATE'] = data1['ALTERED_DATE'].map(lambda val: datetime.datetime.
                                                  fromtimestamp(val).
                                                   strftime('%Y-%m-%d'))
data1['TIME'] = data1['ALTERED_DATE'].map(lambda val: datetime.datetime.
                                                  fromtimestamp(val).
                                                   strftime('%H:%M:%S'))
data1['DAY'] = data1['ALTERED_DATE'].map(lambda val: datetime.datetime.
                                                  fromtimestamp(val).
                                                   strftime('%A'))
data1['DATE_MINS'] = data1['ALTERED_DATE'].map(lambda val: datetime.datetime.
                                                  fromtimestamp(val))

# %%
del data1["NEW_DATE"]

# %%
del data1["MINUTES"]

# %%
 del data1["date"]

# %%
index = data1.index
columns = data1.columns
values = data1.values

# %%
index
# Out:
# RangeIndex(start=0, stop=15715, step=1)

# %%
columns
# Out:
# Index(['id', 'exchange', 'symbol', 'price', 'amount', 'sell', 'DATE', 'TIME',
#        'DAY', 'ALTERED_DATE', 'DATE_MINS'],
#       dtype='object')

# %%
values
# Out:
# array([[183601815, 'bf', 'btceur', ..., 'Friday', 1517529608.0,
#         Timestamp('2018-02-02 02:00:08')],
#        [183601825, 'bf', 'btceur', ..., 'Friday', 1517529609.0,
#         Timestamp('2018-02-02 02:00:09')],
#        [183601823, 'bf', 'btceur', ..., 'Friday', 1517529609.0,
#         Timestamp('2018-02-02 02:00:09')],
#        ...,
#        [185090708, 'bf', 'btceur', ..., 'Saturday', 1517615962.0,
#         Timestamp('2018-02-03 01:59:22')],
#        [185090729, 'bf', 'btceur', ..., 'Saturday', 1517615973.0,
#         Timestamp('2018-02-03 01:59:33')],
#        [185090748, 'bf', 'btceur', ..., 'Saturday', 1517615973.0,
#         Timestamp('2018-02-03 01:59:33')]], dtype=object)

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(values)
# Out:
# numpy.ndarray

# %%
data1["amount"]
# Out:
# 0        0.004568
# 1        0.010000
# 2        0.004568
# 3        0.102395
# 4        0.086580
# 5        0.204920
# 6        0.300000
# 7        0.088007
# 8        0.100000
# 9        0.088007
# 10       0.002000
# 11       0.300000
# 12       0.300000
# 13       0.300000
# 14       0.300000
# 15       0.300000
# 16       0.100000
# 17       0.004885
# 18       0.070000
# 19       0.202579
# 20       0.400000
# 21       0.021287
# 22       0.600000
# 23       0.599912
# 24       0.171953
# 25       0.420000
# 26       0.241449
# 27       1.000000
# 28       0.591953
# 29       0.010000
#            ...
# 15685    0.020000
# 15686    0.392500
# 15687    0.600000
# 15688    0.784800
# 15689    0.002970
# 15690    0.321677
# 15691    0.004848
# 15692    0.004708
# 15693    0.106910
# 15694    0.087147
# 15695    0.046387
# 15696    0.144122
# 15697    0.010000
# 15698    1.500000
# 15699    0.154769
# 15700    0.100000
# 15701    0.099993
# 15702    0.100000
# 15703    0.077792
# ...

# %%
data1[["id", "amount", "DATE"]]
# Out:
#               id    amount        DATE
# 0      183601815  0.004568  2018-02-02
# 1      183601825  0.010000  2018-02-02
# 2      183601823  0.004568  2018-02-02
# 3      183601833  0.102395  2018-02-02
# 4      183601904  0.086580  2018-02-02
# 5      183601906  0.204920  2018-02-02
# 6      183602055  0.300000  2018-02-02
# 7      183602057  0.088007  2018-02-02
# 8      183602052  0.100000  2018-02-02
# 9      183602064  0.088007  2018-02-02
# 10     183602333  0.002000  2018-02-02
# 11     183602610  0.300000  2018-02-02
# 12     183602612  0.300000  2018-02-02
# 13     183602618  0.300000  2018-02-02
# 14     183602629  0.300000  2018-02-02
# 15     183602624  0.300000  2018-02-02
# 16     183602627  0.100000  2018-02-02
# 17     183602676  0.004885  2018-02-02
# 18     183602733  0.070000  2018-02-02
# 19     183602739  0.202579  2018-02-02
# 20     183602735  0.400000  2018-02-02
# 21     183602731  0.021287  2018-02-02
# 22     183602737  0.600000  2018-02-02
# ...

# %%
data1['DAY']=='Friday'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 15685    False
# 15686    False
# 15687    False
# 15688    False
# 15689    False
# 15690    False
# 15691    False
# 15692    False
# 15693    False
# 15694    False
# 15695    False
# 15696    False
# 15697    False
# 15698    False
# 15699    False
# 15700    False
# 15701    False
# 15702    False
# 15703    False
# 15704    False
# 15705    False
# 15706    False
# 15707    False
# 15708    False
# 15709    False
# 15710    False
# 15711    False
# ...

# %%
data1[data1['DATE']=='2018-02-03']
# Out:
#               id exchange  symbol        price    amount   sell        DATE  \
# 15051  185023645       bf  btceur  6904.057104  0.072662   True  2018-02-03
# 15052  185023689       bf  btceur  6904.057104  1.000000   True  2018-02-03
# 15053  185023697       bf  btceur  6904.057104  0.288903   True  2018-02-03
# 15054  185023763       bf  btceur  6904.057104  1.500000   True  2018-02-03
# 15055  185023795       bf  btceur  6904.057104  0.673866   True  2018-02-03
# 15056  185023802       bf  btceur  6904.057104  0.062592   True  2018-02-03
# 15057  185023797       bf  btceur  6904.057104  0.200000   True  2018-02-03
# 15058  185023799       bf  btceur  6904.057104  0.126134   True  2018-02-03
# 15059  185023945       bf  btceur  6903.254400  0.054758   True  2018-02-03
# 15060  185024695       bf  btceur  6884.100000  0.636673   True  2018-02-03
# 15061  185024693       bf  btceur  6884.100000  0.363327   True  2018-02-03
# ...

# %%
data_feb3 = data1[data1['DATE']=='2018-02-03']
sell_info = data_feb3["sell"]
sell_info.dtype
sell_data_int =sell_info.astype(int)
sell_data_int 

def get_seconds(time_str):
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)
time_str = data_feb3["TIME"].astype(str)
time_str.dtype
#get_seconds(time_str)
# Out:
# dtype('O')

# %%
sell_data = data_feb3[["TIME","sell","amount"]]
sell_data
# Out:
#            TIME   sell    amount
# 15051  00:00:59   True  0.072662
# 15052  00:01:01   True  1.000000
# 15053  00:01:01   True  0.288903
# 15054  00:01:05   True  1.500000
# 15055  00:01:09   True  0.673866
# 15056  00:01:09   True  0.062592
# 15057  00:01:09   True  0.200000
# 15058  00:01:09   True  0.126134
# 15059  00:01:23   True  0.054758
# 15060  00:01:53   True  0.636673
# 15061  00:01:53   True  0.363327
# 15062  00:01:54   True  0.570598
# 15063  00:01:54   True  0.029402
# 15064  00:01:54   True  0.900000
# 15065  00:01:54  False  0.363327
# 15066  00:01:55  False  0.044404
# 15067  00:01:56  False  0.002521
# 15068  00:01:58   True  0.426198
# 15069  00:01:58  False  0.214071
# 15070  00:01:58   True  0.198126
# 15071  00:02:00  False  0.205666
# 15072  00:02:08   True  0.205666
# 15073  00:02:21  False  0.059200
# 15074  00:02:42  False  0.070052
# 15075  00:02:45   True  0.070052
# 15076  00:03:33  False  0.282856
# 15077  00:03:35  False  0.291000
# ...

# %%
sell_buy = np.array(sell_data_int)
data_feb3["sell/buy"] = sell_buy
data_feb3
data_feb3["TIME(int)"] = data_feb3["date_integer"]/1000


sales = data_feb3[data_feb3["sell/buy"] ==1]
sales[["amount", "TIME"]]
buy_data = data_feb3[data_feb3["sell/buy"] ==0]
buy_data[["amount", "TIME"]]
# Out:
# /Users/nic_toronga/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/nic_toronga/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#          amount      TIME
# 15065  0.363327  00:01:54
# 15066  0.044404  00:01:55
# 15067  0.002521  00:01:56
# 15069  0.214071  00:01:58
# 15071  0.205666  00:02:00
# 15073  0.059200  00:02:21
# 15074  0.070052  00:02:42
# ...

# %%
data_feb3
del data_feb3["TIME(int)"]

# %%
data_feb3
# Out:
#               id exchange  symbol        price    amount   sell        DATE  \
# 15051  185023645       bf  btceur  6904.057104  0.072662   True  2018-02-03
# 15052  185023689       bf  btceur  6904.057104  1.000000   True  2018-02-03
# 15053  185023697       bf  btceur  6904.057104  0.288903   True  2018-02-03
# 15054  185023763       bf  btceur  6904.057104  1.500000   True  2018-02-03
# 15055  185023795       bf  btceur  6904.057104  0.673866   True  2018-02-03
# 15056  185023802       bf  btceur  6904.057104  0.062592   True  2018-02-03
# 15057  185023797       bf  btceur  6904.057104  0.200000   True  2018-02-03
# 15058  185023799       bf  btceur  6904.057104  0.126134   True  2018-02-03
# 15059  185023945       bf  btceur  6903.254400  0.054758   True  2018-02-03
# 15060  185024695       bf  btceur  6884.100000  0.636673   True  2018-02-03
# 15061  185024693       bf  btceur  6884.100000  0.363327   True  2018-02-03
# ...

# %%
import math
fig = plt.figure()
x =sales["TIME"]
y= sales["amount"]
price = sales["price"]

plt.plot(x, y, '-')



plt.figure(figsize=(500,20))

# %%
print(plt.rcParams.get('figure.figsize'))
# Out:
# [6.0, 4.0]

# %%
y.shape
# Out:
# (324,)

# %%
import math
# %matplotlib inline
x = sales["TIME"]
y = sales["amount"]
price = sales["price"]
plt.rcParams['figure.figsize'] = (30, 15)
#plt.plot(x, y, 'b')
plt.plot(x, price, 'g')
plt.xlabel("Time (H:M:S)")
plt.ylabel("Price")
plt.title("Price Movements Curve")
plt.show()


#plt.figure(figsize=(700,20))
#plt.axis('equal')

# %%
x = sales["TIME"]
y = sales["amount"]

plt.rcParams['figure.figsize'] = (30, 15)
plt.plot(x, y, 'b')
plt.xlabel("Time (H:M:S)")
plt.ylabel("Amount traded")
plt.title("Sell-side Analysis-Time Series")
plt.show()

# %%
data2.shape
# Out:
# (324,)

# %%
t = sales["TIME"]
data1 = sales["price"]
data2 = sales["amount"]

fig, ax1 = plt.subplots()

#color = 'tab:red'
ax1.set_xlabel('TIME (s)')
ax1.set_ylabel('PRICE', color=color)
ax1.plot(t, data1, color="g")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('AMOUNT SOLD', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
np.corrcoef(sales["price"], sales["amount"])
# Out:
# array([[1.        , 0.05752604],
#        [0.05752604, 1.        ]])

# %%
#x_ = buy_data["TIME"]
#y_ = buy_data["amount"]
#plt.plot(x_, y_, '-')

# %%
x_ = buy_data["TIME"]

plt.plot(x_, y_, '-')
plt.xlabel("Time(H:M:S)")
plt.ylabel("Amount Bought")
plt.title("Buy-side Analysis")
plt.show()

# %%
data1['date_integer'] = temp['date']
sell_array = np.array(sell_data_int)
sell_array


data1['sell/buy'] = pd.Series(sell_data_int)
data1
# Out:
# 15051                                                     6904.06
# 15052                                                     6904.06
# 15053                                                     6904.06
# 15054                                                     6904.06
# 15055                                                     6904.06
# 15056                                                     6904.06
# 15057                                                     6904.06
# 15058                                                     6904.06
# 15059                                                     6903.25
# 15060                                                      6884.1
# 15061                                                      6884.1
# 15062                                                      6882.5
# 15063                                                      6882.5
# 15064                                                        6876
# ...

# %%
x_ = buy_data["TIME"]
y_ =buy_data["amount"]
plt.plot(x_, y_, "--")

# %%
data_feb3
# Out:
#               id exchange  symbol        price    amount   sell        DATE  \
# 15051  185023645       bf  btceur  6904.057104  0.072662   True  2018-02-03
# 15052  185023689       bf  btceur  6904.057104  1.000000   True  2018-02-03
# 15053  185023697       bf  btceur  6904.057104  0.288903   True  2018-02-03
# 15054  185023763       bf  btceur  6904.057104  1.500000   True  2018-02-03
# 15055  185023795       bf  btceur  6904.057104  0.673866   True  2018-02-03
# 15056  185023802       bf  btceur  6904.057104  0.062592   True  2018-02-03
# 15057  185023797       bf  btceur  6904.057104  0.200000   True  2018-02-03
# 15058  185023799       bf  btceur  6904.057104  0.126134   True  2018-02-03
# 15059  185023945       bf  btceur  6903.254400  0.054758   True  2018-02-03
# 15060  185024695       bf  btceur  6884.100000  0.636673   True  2018-02-03
# 15061  185024693       bf  btceur  6884.100000  0.363327   True  2018-02-03
# ...

# %%
from scipy.stats import kendalltau
import seaborn as sns
sns.set(style="ticks")

sale_amount = sales["amount"]
x = buy_data["TIME"]
buy_amount = buy_data["amount"]

sns.jointplot(x, sale_amount, stat_func=kendalltau, color="#4CB391")
